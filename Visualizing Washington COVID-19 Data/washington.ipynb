# %% [markdown]
# # Visualizing Washington DC COVID-19 Data

# %% [markdown]
# ### First thing's first
# Let's get this fact straight that I really ~~hate~~ dislike America. **This visualization is for practice purposes only!**

# %% [markdown]
# ## Step 1: Import and inspect

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('datasets/washington-covid.csv')
df.head()
# Out:
#        date state dataQualityGrade   death  deathConfirmed  deathIncrease  \
# 0  20200906    WA                B  1953.0          1953.0              0
# 1  20200905    WA                B  1953.0          1953.0              8
# 2  20200904    WA                B  1945.0          1945.0             10
# 3  20200903    WA                B  1935.0          1935.0              4
# 4  20200902    WA                B  1931.0          1931.0             16
#
#    deathProbable  hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0            NaN        6842.0                  6842.0                  282.0
# 1            NaN        6848.0                  6848.0                  293.0
# 2            NaN        6834.0                  6834.0                  309.0
# 3            NaN        6795.0                  6795.0                  311.0
# 4            NaN        6787.0                  6787.0                  328.0
#
# ...

# %% [markdown]
# ## Step 2: Cleaning up a bit
# It does seem that we could take advantage of the date column as our x-axis.
#
# But first, let us convert its type to `datetime` and then sort it in an ascending order.

# %%
df.date = pd.to_datetime(df.date, format='%Y%m%d')
df = df.sort_values('date', ignore_index=True)
df.head()
# Out:
#         date state dataQualityGrade  death  deathConfirmed  deathIncrease  \
# 0 2020-01-22    WA              NaN    NaN             NaN              0
# 1 2020-01-23    WA              NaN    NaN             NaN              0
# 2 2020-01-24    WA              NaN    NaN             NaN              0
# 3 2020-01-25    WA              NaN    NaN             NaN              0
# 4 2020-01-26    WA              NaN    NaN             NaN              0
#
#    deathProbable  hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0            NaN           NaN                     NaN                    NaN
# 1            NaN           NaN                     NaN                    NaN
# 2            NaN           NaN                     NaN                    NaN
# 3            NaN           NaN                     NaN                    NaN
# 4            NaN           NaN                     NaN                    NaN
#
# ...

# %% [markdown]
# You may now ~~kiss the bride~~ assign the x-axis value.

# %%
x = df.date

# %% [markdown]
# As our y-axis, we will be using the `deathIncrease` column for now.

# %%
y = df.deathIncrease.cumsum()

# %% [markdown]
# ## Step 3: "Let there be visualization!"

# %%
plt.style.use('seaborn')
plt.plot(x, y)

plt.title('Number of Death Increase in WDC')
plt.xlabel('Date')
plt.ylabel('No. Deaths')
plt.xticks(rotation=45)
# Out:
# (array([18293., 18322., 18353., 18383., 18414., 18444., 18475., 18506.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ## Step 4: Sanity check!
# The shape of our plot shooould be the same if we use the `death` column as our y-axis instead.

# %%
y = df.death

plt.plot(x, y)

plt.title('Number of Deaths in WDC')
plt.xlabel('Date')
plt.ylabel('No. Deaths')
plt.xticks(rotation=45)
# Out:
# (array([18322., 18353., 18383., 18414., 18444., 18475., 18506.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# It appears that all is in order!

# %% [markdown]
# # Conclusion
# It does seem that America has sucked **big time** in controlling COVID-19.
#
# Byyye!
